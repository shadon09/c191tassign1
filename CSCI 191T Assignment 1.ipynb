# %% [markdown]
# This is to show off workspace configuration

# %% [markdown]
# Mathplotlib:

# %%
from __future__ import division, print_function, unicode_literals
import matplotlib.pyplot as plt
plt.plot([43,53,32,11])
plt.show()

# %% [markdown]
# NumPy:

# %%
import numpy as np
x = np.linspace(-2, 2, 500)
y = x**2

plt.plot(x, y)
plt.show()

# %%
Pandas:

# %%
import pandas as pd
s = pd.Series([12,-9,-59,42])
s
# Out:
# 0    12
# 1    -9
# 2   -59
# 3    42
# dtype: int64
